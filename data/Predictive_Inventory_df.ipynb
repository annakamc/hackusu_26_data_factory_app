# %%
# read in the predictice inventory df from unity catelog
df = spark.table("dataknobs_predictive_maintenance_and_asset_management.datasets.eletrical_fault_train_test_data")

display(df)

# %%
df = spark.table("dataknobs_predictive_maintenance_and_asset_management.datasets.cnc_data_ai_4_i_2020")

display(df)

# %%
df = spark.table("dataknobs_predictive_maintenance_and_asset_management.datasets.nasa_data_train_test")
display(df)
